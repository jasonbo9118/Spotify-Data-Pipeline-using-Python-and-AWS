# %%
# !pip install spotipy
# Out:
# Requirement already satisfied: spotipy in C:\Users\jason\AppData\Local\Programs\Python\Python313\Lib\site-packages (2.26.0)
# Requirement already satisfied: redis>=3.5.3 in C:\Users\jason\AppData\Local\Programs\Python\Python313\Lib\site-packages (from spotipy) (7.4.0)
# Requirement already satisfied: requests>=2.25.0 in C:\Users\jason\AppData\Local\Programs\Python\Python313\Lib\site-packages (from spotipy) (2.32.5)
# Requirement already satisfied: urllib3>=1.26.0 in C:\Users\jason\AppData\Local\Programs\Python\Python313\Lib\site-packages (from spotipy) (2.6.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\jason\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests>=2.25.0->spotipy) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\jason\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests>=2.25.0->spotipy) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\jason\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests>=2.25.0->spotipy) (2026.2.25)
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth
import os
from dotenv import load_dotenv
import pandas as pd

# %%
CLIENT_ID = os.getenv("SPOTIFY_CLIENT_ID")
CLIENT_SECRET = os.getenv("SPOTIFY_CLIENT_SECRET")
REDIRECT_URI = os.getenv("SPOTIFY_REDIRECT_URI")

# %%
sp = spotipy.Spotify(
    auth_manager=SpotifyOAuth(
        client_id=CLIENT_ID,
        client_secret=CLIENT_SECRET,
        redirect_uri=REDIRECT_URI,
        scope="user-read-private"
    )
)
# Out:
# ---------------------------------------------------------------------------
# SpotifyOauthError                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 sp = spotipy.Spotify(
# ----> 2     auth_manager=SpotifyOAuth(
#       3         client_id=CLIENT_ID,
#       4         client_secret=CLIENT_SECRET,
#       5         redirect_uri=REDIRECT_URI,
#       6         scope="user-read-private"
#       7     )
#       8 )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\spotipy\oauth2.py:301, in SpotifyOAuth.__init__(self, client_id, client_secret, redirect_uri, state, scope, cache_path, username, proxies, show_dialog, requests_session, requests_timeout, open_browser, cache_handler)
#     272 """
#     273 Creates a SpotifyOAuth object
#     274
#    (...)    296                       (takes precedence over `cache_path` and `username`)
#     297 """
#     299 super().__init__(requests_session)
# --> 301 self.client_id = client_id
#     302 self.client_secret = client_secret
#     303 self.redirect_uri = redirect_uri
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\spotipy\oauth2.py:67, in SpotifyAuthBase.client_id(self, val)
#      65 @client_id.setter
#      66 def client_id(self, val):
# ---> 67     self._client_id = _ensure_value(val, "client_id")
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\spotipy\oauth2.py:43, in _ensure_value(value, env_key)
#      41 if _val is None:
#      42     msg = f"No {env_key}. Pass it or set a {env_val} environment variable."
# ---> 43     raise SpotifyOauthError(msg)
#      44 return _val
#
# SpotifyOauthError: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.

# %%
playlist_link = "https://open.spotify.com/playlist/3k4RaZjxSzRIRlrtUEaGka"

# %%
playlist_URI = playlist_link.split("/")[-1].split('?')[0]

# %%
playlist_URI
# Out:
# '3k4RaZjxSzRIRlrtUEaGka'

# %%
data = sp.playlist_tracks(playlist_URI)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\spotipy\oauth2.py:562, in SpotifyOAuth.refresh_access_token(self, refresh_token)
#     555 response = self._session.post(
#     556     self.OAUTH_TOKEN_URL,
#     557     data=payload,
#    (...)    560     timeout=self.requests_timeout,
#     561 )
# --> 562 response.raise_for_status()
#     563 token_info = response.json()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 400 Client Error: Bad Request for url: https://accounts.spotify.com/api/token
#
# During handling of the above exception, another exception occurred:
#
# SpotifyOauthError                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 data = sp.playlist_tracks(playlist_URI)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\spotipy\client.py:718, in Spotify.playlist_tracks(self, playlist_id, fields, limit, offset, market, additional_types)
#     698 """ Get full details of the tracks of a playlist.
#     699
#     700     .. deprecated::
#    (...)    711                              valid types are: track and episode
#     712 """
#     713 warnings.warn(
#     714     "You should use `playlist_items(playlist_id, ...,"
#     715     "additional_types=('track',))` instead",
#     716     DeprecationWarning,
#     717 )
# --> 718 return self.playlist_items(playlist_id, fields, limit, offset,
#     719                            market, additional_types)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\spotipy\client.py:742, in Spotify.playlist_items(self, playlist_id, fields, limit, offset, market, additional_types)
#     730 """ Get full details of the tracks and episodes of a playlist.
#     731
#     732     Parameters:
#    (...)    739                              valid types are: track and episode
#     740 """
#     741 plid = self._get_id("playlist", playlist_id)
# --> 742 return self._get(
#     743     f"playlists/{plid}/items",
#     744     limit=limit,
#     745     offset=offset,
#     746     fields=fields,
#     747     market=market,
#     748     additional_types=",".join(additional_types)
#     749 )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\spotipy\client.py:321, in Spotify._get(self, url, args, payload, **kwargs)
#     318 if args:
#     319     kwargs.update(args)
# --> 321 return self._internal_call("GET", url, payload, kwargs)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\spotipy\client.py:247, in Spotify._internal_call(self, method, url, payload, params)
#     245 if not url.startswith("http"):
#     246     url = self.prefix + url
# --> 247 headers = self._auth_headers()
#     249 if "content_type" in args["params"]:
#     250     headers["Content-Type"] = args["params"]["content_type"]
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\spotipy\client.py:238, in Spotify._auth_headers(self)
#     236     return {}
#     237 try:
# --> 238     token = self.auth_manager.get_access_token(as_dict=False)
#     239 except TypeError:
#     240     token = self.auth_manager.get_access_token()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\spotipy\oauth2.py:503, in SpotifyOAuth.get_access_token(self, code, as_dict, check_cache)
#     494     warnings.warn(
#     495         "You're using 'as_dict = True'."
#     496         "get_access_token will return the token string directly in future "
#    (...)    500         stacklevel=2,
#     501     )
#     502 if check_cache:
# --> 503     token_info = self.validate_token(self.cache_handler.get_cached_token())
#     504     if token_info is not None:
#     505         if self.is_token_expired(token_info):
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\spotipy\oauth2.py:349, in SpotifyOAuth.validate_token(self, token_info)
#     346     return None
#     348 if self.is_token_expired(token_info):
# --> 349     token_info = self.refresh_access_token(
#     350         token_info["refresh_token"]
#     351     )
#     353 return token_info
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\spotipy\oauth2.py:570, in SpotifyOAuth.refresh_access_token(self, refresh_token)
#     568     return token_info
#     569 except requests.exceptions.HTTPError as http_error:
# --> 570     self._handle_oauth_error(http_error)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\spotipy\oauth2.py:119, in SpotifyAuthBase._handle_oauth_error(self, http_error)
#     116     error = response.text or None
#     117     error_description = None
# --> 119 raise SpotifyOauthError(
#     120     f'error: {error}, error_description: {error_description}',
#     121     error=error,
#     122     error_description=error_description
#     123 )
#
# SpotifyOauthError: error: invalid_client, error_description: Invalid client

# %%
data['items']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 data['items']
#
# NameError: name 'data' is not defined

# %%
data['items'][0]['item']['album']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 data['items'][0]['item']['album']
#
# NameError: name 'data' is not defined

# %%
album_list = []
for row in data['items']:
    album_id = row['item']['album']['id']
    album_name = row['item']['album']['name']
    album_release_date = row['item']['album']['release_date']
    album_total_tracks = row['item']['album']['total_tracks']
    album_url = row['item']['album']['external_urls']
    album_element = {'album_id' : album_id, 'album_name' : album_name, 'album_release_date' : album_release_date, 'album_total_tracks' : album_total_tracks, 'album_url' : album_url}
    album_list.append(album_element)

# %%
album_list

# %%
data['items'][0]['item']['artists']

# %%
data['items'][0]['item']['artists']

# %%
artist_list = []
for row in data['items']:
    artist_id = row['item']['artists'][0]['id']
    artist_name = row['item']['artists'][0]['name']
    artist_element = {'artist_id' : artist_id, 'artist_name' : artist_name}
    artist_list.append(artist_element)

# %%
for row in data['items']:
    for key, value in row.items():
        if key == 'item':
            print(value)

# %%
artist_list
